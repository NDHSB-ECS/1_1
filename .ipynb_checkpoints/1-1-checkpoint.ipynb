# %% [markdown]
# Welcome to your first list of exercises.
#
# Let's go over a little bit what each primitive type is and how they're commonly used.

# %% [markdown]
# Integers! If you've ever counted anything in real life, you've used integers.\
# Integers are whole numbers, including positive and negative, as well as 0 itself.\
# Just like in math, they will be used to do any form of arithmetic (adding, subtracting, etc.)\
# Below is an example of designating a variable 'apples' with a numeric value of 5

# %%
apples = 5

# %% [markdown]
# Make sure you hit 'shift+enter' on your keyboard to run that cell, otherwise the notebook won't know that you're assigning that value to that variable.\
# In the next code cell below, please create a variable, called 'oranges' and set it to 7.

# %% [markdown]
# Hopefully you did it correctly. We'll be able to check it with the next chunk of code that I've typed for you.\
# Here, we'll see an example of adding two variables together.
# Run the cell below to see the variables added together.

# %%
print(str(apples+oranges))

# %% [markdown]
# If you did it right, above this markdown cell, you should see '12'
#
# We'll go over the code you just ran a bit further down the line. For now, we'll move onto the next type of primitive.\
# Floats are the inbetweens for integers. They are basically decimal numbers. You can hold up to 8 digits after the . in a decimal number.\
#
# Below, we'll see an example of a float. I am going to assign 'grapes' a value of '8.5'

# %%
grapes = 8.5

# %% [markdown]
# Your turn to assign a value of '6/5' to a variable called 'lemons' in the cell below.

# %% [markdown]
# If you did everything right, the code below should print a value of '9.7'

# %%
print(str(grapes+lemons))

# %% [markdown]
# You're probably tired of numbers. I know I am. Let's move onto something different that's a little less numeric.
#
# Strings are a primitive type that is used to represent a sequence of characters (letters).\
# Below is an example of setting the variable 'question' to the value of 'Who are you?'

# %%
question = "Who are you?"

# %% [markdown]
# Notice for this, we needed to have the string contained in double quotes ("). You can also use single quotes (') to get the same effect. Python will look at this and see that it is a string.\
# In the next cell, please create a variable 'introduction' and set it to a value of 'Hi, my name is [your name here]'

# %% [markdown]
# Just for fun, let's see what happens when we add these two variables together.\
# Please run the following code.

# %%
print(question+introduction)

# %% [markdown]
# Here's a moment where we can practice some jupyter notebook stuff now. Please add your own markdown cell here, and type out what the value you got was.\
# Click the + button to add another cell of any type.![image.png](attachment:image.png)
# You might need to change the type of cell by clicking the dropdown and selecting 'Markdown'
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# A built in function that can tell you what type your variable you have is 'type()'.\
# Here's an example of type being used.

# %%
type(apples)

# %% [markdown]
# Hopefully you got a value of 'int' printed to the screen.\
# Check what the type is for grapes below!

# %% [markdown]
# That should cover it for the basics of primitive types. In this cell, there are questions I would like for you to answer. Create another markdown cell and answer those questions. If you need to, create a code cell to test out things, please do so.\
# This is Exploring Computer Science. If you're not exploring, you're doing something wrong.
# 1. What is the type for the variable 'question'?
# 2. What is the type for the variable 'grapes'?
# 3. Create a variable called fruitSalad, and make it equal to apples+oranges+grapes+lemons. Write the line of code as the answer for this question.
# 4. What is the type for fruitSalad?
# 5. What do you think the purpose is of 'str()' in print(str(apples+oranges))?

# %% [markdown]
# When you are finished, you will commit your work to the github repository.
# Do this by typing here first on the bottom left of the github desktop application:
# ![image.png](attachment:image.png)
# After that, click the commit button that should be enabled after typing a commit message.
# Finally, click the button for pushing to origin at the top of the screen:
# ![image-2.png](attachment:image-2.png)
